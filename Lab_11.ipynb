# %% [markdown]
# <a href="https://colab.research.google.com/github/shivaniyadav525/shivani_yadav/blob/main/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost

        dp[city][mask] = ans
        return ans

    return visit(0, 1)

# %%
graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

print("Minimum travelling cost:", tsp(graph))
# Out:
# Minimum travelling cost: 80

# %%
import sys

def tsp_dp(dist):
    n = len(dist)
    # dp[mask][i] = minimum cost to reach city i with visited set mask
    dp = [[sys.maxsize] * n for _ in range(1 << n)]
    parent = [[-1] * n for _ in range(1 << n)]

    dp[1][0] = 0  # start at city 0

    for mask in range(1, 1 << n):
        for u in range(n):
            if not (mask & (1 << u)):
                continue
            for v in range(n):
                if mask & (1 << v):
                    continue
                new_mask = mask | (1 << v)
                new_cost = dp[mask][u] + dist[u][v]
                if new_cost < dp[new_mask][v]:
                    dp[new_mask][v] = new_cost
                    parent[new_mask][v] = u

    # close the tour: return to city 0
    mask = (1 << n) - 1
    min_cost = sys.maxsize
    last_city = -1
    for i in range(1, n):
        cost = dp[mask][i] + dist[i][0]
        if cost < min_cost:
            min_cost = cost
            last_city = i

    # reconstruct path
    path = []
    mask = (1 << n) - 1
    curr = last_city
    while curr != -1:
        path.append(curr)
        prev = parent[mask][curr]
        mask = mask ^ (1 << curr)
        curr = prev
    path.append(0)
    path.reverse()

    return min_cost, path

# Example usage
# Distance matrix (symmetric, 4 cities for demo)
dist = [
    [0, 10, 15, 20],
    [10, 0, 35, 25],
    [15, 35, 0, 30],
    [20, 25, 30, 0]
]

min_cost, path = tsp_dp(dist)
print("Minimum cost:", min_cost)
print("Path of cities visited:", path)
# Out:
# Minimum cost: 80
# Path of cities visited: [0, 0, 2, 3, 1]

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities

# %%
import sys

def tsp_dp(dist):
    n = len(dist)
    # dp[mask][i] = minimum cost to reach city i with visited set mask
    dp = [[sys.maxsize] * n for _ in range(1 << n)]
    parent = [[-1] * n for _ in range(1 << n)]

    dp[1][0] = 0  # start at city 0

    for mask in range(1, 1 << n):
        for u in range(n):
            if not (mask & (1 << u)):
                continue
            for v in range(n):
                if mask & (1 << v):
                    continue
                new_mask = mask | (1 << v)
                new_cost = dp[mask][u] + dist[u][v]
                if new_cost < dp[new_mask][v]:
                    dp[new_mask][v] = new_cost
                    parent[new_mask][v] = u

    # close the tour: return to city 0
    mask = (1 << n) - 1
    min_cost = sys.maxsize
    last_city = -1
    for i in range(1, n):
        cost = dp[mask][i] + dist[i][0]
        if cost < min_cost:
            min_cost = cost
            last_city = i

    # reconstruct path
    path = []
    mask = (1 << n) - 1
    curr = last_city
    while curr != -1:
        path.append(curr)
        prev = parent[mask][curr]
        mask = mask ^ (1 << curr)
        curr = prev
    path.append(0)
    path.reverse()

    return min_cost, path

# -------------------------------
# Take input from user
# -------------------------------
n = int(input("Enter number of cities: "))
print("Enter the distance matrix row by row:")

dist = []
for i in range(n):
    row = list(map(int, input().split()))
